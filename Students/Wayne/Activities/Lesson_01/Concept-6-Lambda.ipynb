# %%
lambda x: x*2
# Out:
# <function __main__.<lambda>(x)>

# %%
lambda x:x*2

# %%
(lambda x:x*2)(4)
# Out:
# 8

# %%
l = [lambda x, y: x+y]

# %%
type(l[0])
# Out:
# function

# %%
leg = ((27.154167, -80.195663), (29.195168, -81.002998), 129.7748)
start= lambda x: x[0]
end  = lambda x: x[1]
dist = lambda x: x[2]
dist(leg)
# Out:
# 129.7748
